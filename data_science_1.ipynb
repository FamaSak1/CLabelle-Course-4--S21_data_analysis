# %% [markdown]
# # Data Analysis and Data Science
# ## Be curious about the data
#
# By: Caroline Labelle
# <br>For: BCM6065-65
#
# <br>
# Date: July  6th 2021
#
# <hr style="border:1px solid black"> </hr>

# %%
 var = "yeah!"

# %% [markdown]
# ## Installing Python libraries
#
# Befor using (or importing) a library in Python, you first need to install it!. This step only need to be done once for each library: once istalled, you will have access to all the libraries from your coding environment.
#
# Ressource: https://pip.pypa.io/en/stable/user_guide/

# %%
### Installing Pandas
### If not already installed
# !pip3 install -U pandas
# Out:
# Requirement already up-to-date: pandas in ./.local/lib/python3.6/site-packages (1.1.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /soft/bioinfo/linux_RH7/python-3.6.7/lib/python3.6/site-packages (from pandas) (2.7.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in /soft/bioinfo/linux_RH7/python-3.6.7/lib/python3.6/site-packages (from pandas) (1.15.4)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in ./.local/lib/python3.6/site-packages (from pandas) (2021.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /soft/bioinfo/linux_RH7/python-3.6.7/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas) (1.11.0)
# You are using pip version 18.1, however version 21.1.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
### Installing seaborn
# !pip3 install --user seaborn
# Out:
# Collecting seaborn
#   Downloading https://files.pythonhosted.org/packages/68/ad/6c2406ae175f59ec616714e408979b674fe27b9587f79d59a528ddfbcd5b/seaborn-0.11.1-py3-none-any.whl (285kB)
#     100% |████████████████████████████████| 286kB 4.6MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15 in /soft/bioinfo/linux_RH7/python-3.6.7/lib/python3.6/site-packages (from seaborn) (1.15.4)
# Requirement already satisfied: pandas>=0.23 in ./.local/lib/python3.6/site-packages (from seaborn) (1.1.5)
# Collecting matplotlib>=2.2 (from seaborn)
#   Downloading https://files.pythonhosted.org/packages/09/03/b7b30fa81cb687d1178e085d0f01111ceaea3bf81f9330c937fb6f6c8ca0/matplotlib-3.3.4-cp36-cp36m-manylinux1_x86_64.whl (11.5MB)
#     100% |████████████████████████████████| 11.5MB 728kB/s eta 0:00:01    97% |███████████████████████████████▎| 11.3MB 28.2MB/s eta 0:00:01
# Collecting scipy>=1.0 (from seaborn)
#   Downloading https://files.pythonhosted.org/packages/c8/89/63171228d5ced148f5ced50305c89e8576ffc695a90b58fe5bb602b910c2/scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9MB)
#     100% |████████████████████████████████| 25.9MB 343kB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.2 in ./.local/lib/python3.6/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /soft/bioinfo/linux_RH7/python-3.6.7/lib/python3.6/site-packages (from pandas>=0.23->seaborn) (2.7.3)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 (from matplotlib>=2.2->seaborn)
#   Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
#     100% |████████████████████████████████| 71kB 5.0MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1 (from matplotlib>=2.2->seaborn)
#   Downloading https://files.pythonhosted.org/packages/a7/1b/cbd8ae738719b5f41592a12057ef5442e2ed5f5cb5451f8fc7e9f8875a1a/kiwisolver-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#     100% |████████████████████████████████| 1.1MB 4.1MB/s eta 0:00:01
# Collecting pillow>=6.2.0 (from matplotlib>=2.2->seaborn)
#   Downloading https://files.pythonhosted.org/packages/32/09/762ac8751f6e937eb5137a4eca7cd0b679fa921f35e3df1f24f568004252/Pillow-8.3.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0MB)
#     100% |████████████████████████████████| 3.0MB 353kB/s eta 0:00:01
# Collecting cycler>=0.10 (from matplotlib>=2.2->seaborn)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.5 in /soft/bioinfo/linux_RH7/python-3.6.7/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->seaborn) (1.11.0)
# Installing collected packages: pyparsing, kiwisolver, pillow, cycler, matplotlib, scipy, seaborn
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.3.4 pillow-8.3.0 pyparsing-2.4.7 scipy-1.5.4 seaborn-0.11.1
# You are using pip version 18.1, however version 21.1.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
### Installing scikit-learn
# !pip install --user scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/f5/ef/bcd79e8d59250d6e8478eb1290dc6e05be42b3be8a86e3954146adbc171a/scikit_learn-0.24.2-cp36-cp36m-manylinux1_x86_64.whl (20.0MB)
#     100% |████████████████████████████████| 20.0MB 442kB/s eta 0:00:01
# Collecting joblib>=0.11 (from scikit-learn)
#   Downloading https://files.pythonhosted.org/packages/55/85/70c6602b078bd9e6f3da4f467047e906525c355a4dacd4f71b97a35d9897/joblib-1.0.1-py3-none-any.whl (303kB)
#     100% |████████████████████████████████| 307kB 5.2MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied: scipy>=0.19.1 in ./.local/lib/python3.6/site-packages (from scikit-learn) (1.5.4)
# Requirement already satisfied: numpy>=1.13.3 in /soft/bioinfo/linux_RH7/python-3.6.7/lib/python3.6/site-packages (from scikit-learn) (1.15.4)
# Installing collected packages: joblib, threadpoolctl, scikit-learn
# Successfully installed joblib-1.0.1 scikit-learn-0.24.2 threadpoolctl-2.1.0
# You are using pip version 18.1, however version 21.1.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# <hr style="border:1px dashed black"> </hr>

# %% [markdown]
# ## Importing the data
#
# Ressource: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
## Import Pandas
import pandas as pd

# %%
# !ls ##to find the files names
# Out:
# breast_cancer_metametric.tsv  exercises_1.ipynb    Part_1-student.ipynb
# Course1_Fama.ipynb	      Fama-course 2.ipynb  Part_2-student.ipynb
# Course1.ipynb		      iris.tsv		   seq_100.txt
# data_science_1.ipynb	      kmers.tsv		   test.csv

# %%
## Define variable with file name
fn = "iris.tsv"

# %%
## Read ans save data into variable as a dataframe
data = pd.read_csv(fn,sep ="\t", header = 0)

# %%
## Show 5 first row of DF
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <hr style="border:1px dashed black"> </hr>

# %% [markdown]
# ## Exploring the data

# %%
### How many samples and variables do we have? (rows, coloumns)
data.shape
# Out:
# (150, 5)

# %%
### What are the variables? usually the columns names
data.columns.values
# Out:
# array(['# sepal_length:lin', 'sepal_width:lin', 'petal_length:lin',
#        'petal_width:lin', 'label:nom'], dtype=object)

# %%
### For each of the measurements variables
### What are the min. max, mean and median values? useful to know the range of your values

print("Min. values: ")
print(data.min(axis=0))

print("\nMax. values: ")
print(data.max(axis=0))

print("\nMean. values: ")
print(data.mean(axis=0))

print("\nMedian. values: ")
print(data.median(axis=0))
# Out:
# Min. values:
# # sepal_length:lin            4.3
# sepal_width:lin                 2
# petal_length:lin                1
# petal_width:lin               0.1
# label:nom             Iris-setosa
# dtype: object
#
# Max. values:
# # sepal_length:lin               7.9
# sepal_width:lin                  4.4
# petal_length:lin                 6.9
# petal_width:lin                  2.5
# label:nom             Iris-virginica
# dtype: object
#
# Mean. values:
# # sepal_length:lin    5.843333
# sepal_width:lin       3.057333
# petal_length:lin      3.758000
# petal_width:lin       1.199333
# dtype: float64
#
# Median. values:
# # sepal_length:lin    5.80
# sepal_width:lin       3.00
# petal_length:lin      4.35
# petal_width:lin       1.30
# dtype: float64

# %%
### How many "types" of iris do we consider? or how many cell lines do we whave
data.label.nunique()
# Out:
# 3

# %%
### What are the "types" of iris that we consider? 
data.label.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ![alt text](https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png)

# %% [markdown]
# <hr style="border:1px dashed black"> </hr>

# %% [markdown]
# ## Visualize the data
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# Example gallery: https://seaborn.pydata.org/examples/index.html<br>
# Helpfull tutorial: https://seaborn.pydata.org/tutorial.html

# %%
## Import the seaborn library
## You might have to install it first!
import seaborn as sns
# nice for exploration, but maybe not for publication cause it dont give aaaaall the statistical metrics

# %% [markdown]
# We can set global theme parameters (<code>sns.set_theme</code>) that will be apply to all plots.
#
# Ressource: https://seaborn.pydata.org/generated/seaborn.set_theme.html

# %% [markdown]
# The <code>context</code> will affect things like the size of the labels, lines, and other elements of the plot, but not the overall style. You can choose between "notebook", "paper", "talk" and "poster".
#
# The <code>style</code> will affect things like the color of the axes, whether a grid is enabled by default, and other aesthetic elements. You can choose between "darkgrid", "whitegrid", "dark", "white", "ticks".
#
# The <code>palette</code> will define the colors used when plotting.

# %%
sns.set(rc={'figure.figsize':(9, 4)})
sns.set_theme(context="notebook", style="white", palette="Set2")

# %% [markdown]
# ![alt text](https://seaborn.pydata.org/_images/function_overview_8_0.png)

# %% [markdown]
# The general syntax to generat a ploft/figure with seaborn:
#
# ```python
# sns.type_of_plot(data=data_df, x=col_name, (y=col_name), [ARGS])
# ```
#
# <br><br>
# For instance, we can generate a plot with the values of sepal length represented by histograms:
#
# ```python
# sns.histplot(data, x="sepal_width")
# ```

# %%
### Plot sepal lenght as a histogram
sns.histplot(data=data, x="sepal_width")
sns.despine()

# %% [markdown]
# ### Exploring distribution of measurements
#
# A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within disrete bins.
#
# Ressource: https://seaborn.pydata.org/generated/seaborn.histplot.html?highlight=histplot#seaborn.histplot

# %%
### We want to look a the distribution of measurements for sepal length
sns.histplot(data=data, x="sepal_length")
sns.despine()

# %% [markdown]
# ---
# **bins => str, number, vector, or a pair of such values**<br>
# Generic bin parameter that can be the name of a reference rule, the number of bins, or the breaks of the bins.

# %%
### Let's use more bins...
sns.histplot(data, x="sepal_length", bins=25) ##ici on divise tout en 25 bins
sns.despine()

# %% [markdown]
# ---
# **binwidth => number or pair of numbers** <br>
# Width of each bin, overrides bins

# %%
### Let's use smaller bins...
sns.histplot(data, x="sepal_length", binwidth=0.1) 
##ici le premier groupe commence à 3,75 et tu augmente à chaque 0,1
sns.despine()

# %% [markdown]
# ---
# **hue => vector or key in data**<br>
# Semantic variable that is mapped to determine the color of plot elements.

# %%
### We want the distribution to be label-specific to each kind of flowers
sns.histplot(data, x="sepal_length", binwidth=0.1, hue="label")
sns.despine()

# %% [markdown]
# ---
# **multiple ==> {“layer”, “dodge”, “stack”, “fill”}** <br>
# Approach to resolving multiple elements when semantic mapping creates subsets. Only relevant with univariate data.

# %%
### Make our plot more readable (specifies how i want seaborn to illustrate multiple datas)
p = sns.histplot(data, x="sepal_length", binwidth=0.1, hue="label", multiple = "stack")

### Add a title
p.set_title("stacked distribution of sepal lenght - IRIS")
sns.despine()

# %% [markdown]
# ***
# We can use <code>displot</code>, instead of <code>histplot</code>, which will allow us to draw distribution plots onto a FacetGrid a.k.a have a figure with various subplots.<br>
#
# Ressource: https://seaborn.pydata.org/generated/seaborn.displot.html?highlight=displot#seaborn.displot

# %% [markdown]
# **kind => {“hist”, “kde”, “ecdf”}**<br>
# Approach for visualizing the data. Selects the underlying plotting function and determines the additional set of valid parameters.

# %% [markdown]
# **row, col ==> vectors or keys in data**<br>
# Variables that define subsets to plot on different facets.

# %% [markdown]
# Let's try it:
#
# ```python
# ### Modify the following line of code so that:
# ### --> you are using displot()
# ### --> you are representing the sepal_length with histogram
# ### --> you have a figure of 1 row and 3 columns: one column per label
#
# sns.histplot(data, x="sepal_length", binwidth=0.1, hue="label", multiple="stack")
# sns.despine()
# ```

# %%
### Write your code her
sns.displot(data, x="sepal_length", binwidth=0.1, hue="label", kind="hist", col="label") #without the hue it gives
#the same colour
sns.despine()
##the figures can be saved by right clicking on it if you are on a note book

# %% [markdown]
# What do you observe in the above figure?
# ***
# Once you have figure, you can save it in a vector format (<code>.pdf</code> or <code>.svg</code>). Figures can then be easily modified/edited in apps such as Illustrator and Affinity Design.

# %%
### Save your last figure as a pdf if you are not in a notebook
p = sns.displot(data, x="sepal_length", binwidth=0.1, hue="label", multiple="stack", kind="hist", col="label")
p.despine()

p.savefig("distribution of sepal lenght - IRIS.pdf")

# %% [markdown]
# We have been representing the distributions in terms of "count of occurrences" (y-axis). It is worth noting that the distribution statistic can easily be change with the <code>stat</code> argument.
#
# **stat => {“count”, “frequency”, “density”, “probability”}**
#
# Aggregate statistic to compute in each bin.
# * **count** shows the number of observations
# * **frequency** shows the number of observations divided by the bin width
# * **density** normalizes counts so that the area of the histogram is 1
# * **probability** normalizes counts so that the sum of the bar heights is 1

# %%
p = sns.displot(data, x="sepal_length", binwidth=0.1, hue="label", multiple="stack", kind="hist", col="label", stats=density)
p.despine()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-c0eddb997eda> in <module>
# ----> 1 p = sns.displot(data, x="sepal_length", binwidth=0.1, hue="label", multiple="stack", kind="hist", col="label", stats=density)
#       2 p.despine()
#
# NameError: name 'density' is not defined

# %% [markdown]
# ### Visualizing relationships
#
# A scatterplot is a classic visualization tool that represents the relationship between <code>x</code> and <code>y</code>. Different subsets of the data can be shown by altering the color, size and style of the marker.
#
# Even though it is possible to show up to three dimensions independently by using all three semantic types (color, size and style), this style of plot can be hard to interpret and is often ineffective.
#
# Ressource: https://seaborn.pydata.org/generated/seaborn.scatterplot.html?highlight=scatterplot#seaborn.scatterplot

# %%
### We are interested in the relation between sepal lenght and peta length
### Plot this relation as a scatter plot
sns.scatterplot(data=data, x="sepal_length", y="petal_length")
sns.despine()

# %% [markdown]
# ***
# **hue => vector or key in data**<br>
# Grouping variable that will produce points with different colors. Can be either categorical or numeric, although color mapping will behave differently in latter case.

# %%
### Color the marker based on their label
sns.scatterplot(data=data, x="sepal_length", y="petal_length", hue="label")
sns.despine()

# %%
data.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        label
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %% [markdown]
# ***
# **size => vector or key in data**<br>
# Grouping variable that will produce points with different sizes. Can be either categorical or numeric, although size mapping will behave differently in latter case.
# <br><br>
# **style => vector or key in data**<br>
# Grouping variable that will produce points with different markers. Can have a numeric dtype but will always be treated as categorical.

# %%
### How could we incorporate label, petal_width and sepal_width identification
### into our petal_length vs. sepal_length scatterplot?

## marker color: sepal_width
## marker size: petal_withd
## marker style: label

sns.scatterplot(data=data, x="sepal_length", y="petal_length", hue="sepal_width", size="petal_width", style="label")
sns.despine()

# %%
### To change figure size, we need to use the Matplotlib library 
### It was installed as dependency of seaborn: you just have to import it!
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python: the Seaborn library is based on matplotlib.<br>
#
# Ressource: https://matplotlib.org/stable/index.html
#
# ***
# <code>plt.figure</code> implements a top level figure object that will hold all plot element. We can specify various arguments such as the size of the figure, it's facecolor and esdgecolor.
#
# Ressource: https://matplotlib.org/stable/api/figure_api.html?highlight=figure#module-matplotlib.figure

# %%
### Define a figure object with the desired dimension
fig = plt.figure(figsize =( 15,6))
p = sns.scatterplot(data=data, x="sepal_length", y="petal_length", hue="petal_width", size="sepal_width", 
                style="label")

### We can also play with our legend
## Labels in two columns
plt.legend(bbox_to_anchor=(1,1))
## Legend outside of plot
plt.legend(ncol=3)



### Add a descriptive title
#plt.title("Representation of all variables")
plt.title("Representation of all variables")
sns.despine()
### save figure as pdf
#fig.savefig()

# %% [markdown]
# ***
# It is hard to fit multiple pairwise relationships from a dataset into a single plot. The rendered plot can be hard to read and interpret!
#
# <br>
# Instead of using <code>scatteplot</code>, let's try <code>pairplot</code>!
#
# This  will create a grid of Axes such that each numeric variable in data will by shared across the y-axes across a single row and the x-axes across a single column. The diagonal plots are treated differently: a univariate distribution plot is drawn to show the marginal distribution of the data in each column.
#
# It is also possible to show a subset of variables or plot different variables on the rows and columns.
#
# Ressource: https://seaborn.pydata.org/generated/seaborn.pairplot.html?highlight=pairplot#seaborn.pairplot

# %%
data.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        label
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
### Plot all pairwise relationships between sepal_lenght, petal_length, sepal_width and petal_width
### Color samples based on their label
### The diagonal should contain histogram

sns.pairplot(data, hue="label")
sns.despine()

# %% [markdown]
# There is some redundance in the figure obtained...
#
# We can specify to plot only the lower triangle with <code>corner=True</code>.

# %%
### Only plot lower triangle of the pairwise plot, 
p = sns.pairplot(data, hue="label", diag_kind="hist", corner=True) ##to take off the redunduncy

### Save figure to PDF
#p.savefig()

# %% [markdown]
# What do you observe in the above figure?

# %% [markdown]
# ### Visualizing statistical relationships
#
# Many datasets contain multiple quantitative variables, and the goal of an analysis is often to relate those variables to each other. Seaborn can be very useful as it allows to use statistical models to estimate a simple relationship between two noisy sets of observations.
#
# Remember that Seaborn is a *visualization* tool and not a statistical library: you test for linear and non-linear correlations between subsets but you will not have the associated coefficient or other statistical metrics.

# %% [markdown]
# The two main functions to visualize a linear relationship are <code>regplot()</code> and <code>lmplot()</code>. Both functions draw a scatterplot of two variables, <code>x</code> and <code>y</code>, and then fit the regression model <code>y ~ x</code> and plot the resulting regression line and a 95% confidence interval for that regression

# %% [markdown]
# ***
# <code>regplot()</code> always shows a single relationship (i.e. no <code>hue</code> argument).
#
# Ressource: https://seaborn.pydata.org/generated/seaborn.regplot.html#seaborn.regplot

# %%
### Plot linear regression between sepal_lenght and sepal_width
sns.regplot(data=data, x="sepal_length", y="sepal_width")

### Add a title
plt.title("Linear regression")
sns.despine()

# %% [markdown]
# ***
# <code>lmplot()</code> combines <code>regplot()</code> with <code>FacetGrid</code> to provide an easy interface to show a linear regression on “faceted” plots that allow you to explore interactions with up to three additional categorical variables.
#
# Ressource: https://seaborn.pydata.org/generated/seaborn.lmplot.html#seaborn.lmplot

# %%
### Plot linear regression between sepal_lenght and sepal_width
### The regression should be label-specific
sns.lmplot(data=data, x="sepal_length", y="sepal_width", hue="label", truncate=False)

### Add a title
plt.title("Linear correlation label-specific")
sns.despine()

# %% [markdown]
# **truncate => bool, optional**
#
# If True, the regression line is bounded by the data limits. If False, it extends to the x axis limits.

# %%
### Plot linear regression between sepal_lenght and sepal_width
### The regression should be label-specific
### We want a figure of 1 row and 3 columns: one column per label
sns.lmplot(data=data, x="sepal_length", y="sepal_width",hue="label",truncate=False, col="label", )
sns.despine()

# %% [markdown]
# ***
# It is possible to only show the linear regresion, i.e. remove the scatter plot
#
# **scatter => bool, optional**
#
# If True, draw a scatterplot with the underlying observations (or the x_estimator values).

# %%
### Obly show the linear regression
sns.lmplot(data=data, x="sepal_length", y="sepal_width", hue="label", scatter=False, truncate=False)

### Add a title
plt.title("Linear regression - Sepal length vs. width")
sns.despine()

# %% [markdown]
# ***
# Various parameters of the linear regression can be adjusted for both <code>regplot()</code> and <code>lmplot()</code>:
#
# * **ci => int in [0, 100] or None, optional** <br>Size of the confidence interval for the regression estimate. This will be drawn using translucent bands around the regression line. The confidence interval is estimated using a bootstrap; for large datasets, it may be advisable to avoid that computation by setting this parameter to None.
# <br>
#
# * **x_estimator => callable that maps vector -> scalar, optional** <br>Apply this function to each unique value of x and plot the resulting estimate. This is useful when x is a discrete variable. If x_ci is given, this estimate will be bootstrapped and a confidence interval will be drawn.
# <br>
#
# * **logistic => bool, optional** <br>If True, assume that y is a binary variable and use statsmodels to estimate a logistic regression model. Note that this is substantially more computationally intensive than linear regression, so you may wish to decrease the number of bootstrap resamples (n_boot) or set ci to None.
# <br>
#
# * **logx => bool, optional** <br>If True, estimate a linear regression of the form y ~ log(x), but plot the scatterplot and regression model in the input space. Note that x must be positive for this to work.
# <br>

# %% [markdown]
# ### Other interesting visualisation

# %% [markdown]
# <code>jointplot()</code> will draw a plot of two variables with bivariate and univariate graphs.
#
# Ressource: https://seaborn.pydata.org/generated/seaborn.jointplot.html?highlight=jointplot#seaborn.jointplot

# %%
sns.jointplot(data=data, x="sepal_length", y="sepal_width")
sns.despine()

# %%
### Use kind = "reg"
sns.jointplot(data=data, x="sepal_length", y="sepal_width", kind="reg")
sns.despine()

# %% [markdown]
# ***
# <code>rugplot()</code> will Plot marginal distributions by drawing ticks along the x and y axes..
#
# Ressource: https://seaborn.pydata.org/generated/seaborn.rugplot.html?highlight=rugplot#seaborn.rugplot

# %%
sns.scatterplot(data=data, x="sepal_length", y="sepal_width", hue="label")
sns.rugplot(data=data, x="sepal_length", y="sepal_width")
sns.despine()
